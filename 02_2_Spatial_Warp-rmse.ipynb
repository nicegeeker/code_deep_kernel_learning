# %%
import gpytorch
import matplotlib.pyplot as plt
import torch
from torch import nn

from func_algorithms import *
from func_data_generation import *
from func_polygon import *
from utils import *
from warp_units import *

# from torchsummary import summary


dtype = torch.double
device = "cuda" if torch.cuda.is_available() else "cpu"
# device =  "cpu"
print("Using {} device".format(device))

import tqdm

torch.set_default_dtype(dtype)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from datetime import datetime

from torch.utils.tensorboard import SummaryWriter
# Out:
# Using cuda device

# %%
class WarpModel(torch.nn.Sequential):
    def __init__(self):
        super(WarpModel, self).__init__()
        self.add_module(
            "axial_dim0", AxialWarpUnit(dim=0, res=50, grad=20, lims=[0, 1.0])
        )
        self.add_module(
            "axial_dim1", AxialWarpUnit(dim=1, res=50, grad=20, lims=[-1.0, 0])
        )
        self.add_module("rbf_seq1", rbfunit_sequential(res=2, ylim=[-1.0, 0.0]))
        self.add_module("rbf_seq2", rbfunit_sequential(res=3, ylim=[-1, 0]))
        self.add_module("mobius", MobiusWarpUnit())


class GPRegressionModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood, warp_model):
        super(GPRegressionModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ZeroMean()
        #             self.covar_module = gpytorch.kernels.GridInterpolationKernel(
        #                 gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(ard_num_dims=2)),
        #                 num_dims=2, grid_size=100
        #             )
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
        #         self.covar_module = gpytorch.kernels.SpectralMixtureKernel(
        #             num_mixtures=4, ard_num_dims=2
        #         )
        #         self.covar_module2 = gpytorch.kernels.ScaleKernel(
        #             gpytorch.kernels.PolynomialKernel(1, active_dimes=[0])
        #             * gpytorch.kernels.PolynomialKernel(1, active_dimes=[1])
        #         )
        #         self.covar_module2 = gpytorch.kernels.ScaleKernel(
        #             gpytorch.kernels.PolynomialKernel(power=2)
        #         )
        self.covar_module2 = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
        self.space_transform = warp_model

        #         self.register_parameter(
        #             name="offset", parameter=torch.nn.Parameter(torch.zeros(1, 2))
        #         )
        self.w1 = 1
        self.w2 = 1

    def forward(self, x):
        # We're first putting our data through a deep net (feature extractor)
        # We're also scaling the features so that they're nice values
        projected_x = self.space_transform(x)
        projected_x = projected_x - projected_x.min(0)[0]
        projected_x = 2 * (projected_x / projected_x.max(0)[0]) - 1

        mean_x = self.mean_module(x)
        covar_x = self.w1 * self.covar_module(
            projected_x
        ) + self.w2 * self.covar_module2(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
data_num = 5
sensor_num = 200  # [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

# load data
data_filename = DATA_PATH + "/datasets_" + str(data_num) + ".hd5f"

if os.path.exists(data_filename):
    with h5py.File(data_filename, "r") as f1:
        coords = f1["coords"][...]
        true_rss = f1["true_rss"][...]
        observed_rss = f1["observed_rss"][...]
        train_X = f1["train_" + str(sensor_num) + "/train_X"][...]
        train_y = f1["train_" + str(sensor_num) + "/train_y"][...]
        idx = f1["train_" + str(sensor_num) + "/idx"][...]

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
plot_heatmap(coords, observed_rss, ax=axes[0], robust=True, cbar=True)
plot_heatmap(
    coords,
    observed_rss,
    mask_idx=idx,
    ax=axes[1],
    cbar=True,
)

# %%
# Normalize train_X to 0-1
data_X_tensor = torch.from_numpy(train_X).to(device) / 1000
coords_tensor = torch.from_numpy(coords).to(device) / 1000

train_y_tensor = torch.from_numpy(train_y).to(device)
train_y_mean = train_y_tensor.mean()
data_y_tensor = train_y_tensor - train_y_mean
# train_y_sigma = torch.sqrt(train_y_tensor.var())
# train_y_tensor = (train_y_tensor - train_y_mean) / train_y_sigma

# %%
train_num = int(sensor_num * 0.9)
train_X_tensor = data_X_tensor[0:train_num, :]
train_y_tensor = data_y_tensor[0:train_num]
test_X_tensor = data_X_tensor[train_num:, :]
test_y_tensor = data_y_tensor[train_num:]

# %%
test_X_tensor.shape
# Out:
# torch.Size([20, 2])

# %%
# Define and initialize model
warp_model = WarpModel().to(device)
likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)
gp_model = GPRegressionModel(
    train_x=train_X_tensor,
    train_y=train_y_tensor,
    likelihood=likelihood,
    warp_model=warp_model,
).to(device)
gp_model.likelihood.noise = 0.2
gp_model.covar_module2.base_kernel.lengthscale = 0.0828
gp_model.covar_module2.outputscale = 30.51

# %%
chessboard_from_model(warp_model)

# %%
for name, param in gp_model.named_parameters():
    print(f"Layer:{name} | Size:{param.size()} | Values : {param} \n")
# #     print(f"Layer:{name} | Size:{param.size()} |  \n")
# Out:
# Layer:likelihood.noise_covar.raw_noise | Size:torch.Size([1]) | Values : Parameter containing:
# tensor([-1.5083], device='cuda:0', requires_grad=True)
#
# Layer:covar_module.raw_outputscale | Size:torch.Size([]) | Values : 0.0
#
# Layer:covar_module.base_kernel.raw_lengthscale | Size:torch.Size([1, 1]) | Values : Parameter containing:
# tensor([[0.]], device='cuda:0', requires_grad=True)
#
# Layer:covar_module2.raw_outputscale | Size:torch.Size([]) | Values : 30.509999999999945
#
# Layer:covar_module2.base_kernel.raw_lengthscale | Size:torch.Size([1, 1]) | Values : Parameter containing:
# tensor([[-2.4496]], device='cuda:0', requires_grad=True)
#
# Layer:space_transform.axial_dim0.weight_true | Size:torch.Size([1, 50]) | Values : Parameter containing:
# tensor([[-4.4672e-01,  1.2802e-03,  6.4676e-01, -5.6844e-01, -1.4043e+00,
#          -2.8077e-01,  1.3429e+00,  5.2364e-01,  1.4295e-01, -3.3839e-01,
#          -8.3826e-01,  1.6383e-01, -1.9557e-01, -1.4973e+00,  4.6856e-01,
#           5.4401e-01,  1.5657e+00,  4.1638e-01,  1.6870e-01, -3.8100e-01,
#          -1.5965e-01, -1.5130e+00,  2.4109e+00, -2.5086e+00,  8.9363e-01,
#           9.4429e-02, -1.4822e+00,  1.3256e+00, -8.2380e-01,  3.4350e-01,
#           4.6118e-01, -8.3201e-01,  3.1450e-01,  2.8457e-01,  4.8977e-01,
#           8.7610e-01,  6.3553e-01, -4.4363e-01, -3.3633e-01, -3.7571e-01,
#          -1.4736e+00,  1.5382e+00,  1.1654e+00, -1.7225e-01, -1.5315e+00,
#          -2.3450e-01,  4.6986e-01, -2.0109e+00, -1.0251e-01,  1.4023e+00]],
#        device='cuda:0', requires_grad=True)
#
# Layer:space_transform.axial_dim1.weight_true | Size:torch.Size([1, 50]) | Values : Parameter containing:
# tensor([[ 1.5073,  1.6517, -1.0189,  0.9692, -0.3881, -0.0586, -0.1006,  0.7755,
#          -1.6359, -0.4325, -0.7996,  0.3813,  0.5384, -0.6729, -1.6324, -0.0734,
#          -1.6950,  0.9078, -0.5487, -1.3969,  0.4131,  1.2358,  0.3398, -0.2959,
#           0.7799, -0.2984,  1.2748, -1.8631,  0.5631,  0.2566, -0.3267,  1.2324,
#          -0.1545,  0.2126, -1.0817, -0.3813,  0.4875,  0.3363,  0.0845, -1.0653,
#          -0.5198,  0.7791,  2.1801,  0.1445, -1.2319, -0.5888,  0.9051, -0.4587,
#           0.1588, -0.5813]], device='cuda:0', requires_grad=True)
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num0.weight_true | Size:torch.Size([]) | Values : 1.7642762091195878
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num1.weight_true | Size:torch.Size([]) | Values : 0.39861574675901124
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num2.weight_true | Size:torch.Size([]) | Values : -1.1933527651601181
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num3.weight_true | Size:torch.Size([]) | Values : 0.5197543444374921
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num4.weight_true | Size:torch.Size([]) | Values : 2.0520412084747446
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num5.weight_true | Size:torch.Size([]) | Values : 1.7333698114090554
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num6.weight_true | Size:torch.Size([]) | Values : 0.2312661245406955
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num7.weight_true | Size:torch.Size([]) | Values : -0.3621215090805457
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num8.weight_true | Size:torch.Size([]) | Values : -0.3765547702573753
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num9.weight_true | Size:torch.Size([]) | Values : -1.0563775333142846
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num10.weight_true | Size:torch.Size([]) | Values : -1.1273801457746344
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num11.weight_true | Size:torch.Size([]) | Values : 1.8793525472924608
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num12.weight_true | Size:torch.Size([]) | Values : 0.3364560939120779
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num13.weight_true | Size:torch.Size([]) | Values : 1.0746885079436075
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num14.weight_true | Size:torch.Size([]) | Values : 0.5944740232597387
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num15.weight_true | Size:torch.Size([]) | Values : -1.0106487596662441
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num16.weight_true | Size:torch.Size([]) | Values : -3.135938426474972
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num17.weight_true | Size:torch.Size([]) | Values : -1.573758016356312
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num18.weight_true | Size:torch.Size([]) | Values : 2.1958149363946684
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num19.weight_true | Size:torch.Size([]) | Values : -0.25405053386093357
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num20.weight_true | Size:torch.Size([]) | Values : 0.6554516137737634
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num21.weight_true | Size:torch.Size([]) | Values : 0.42847900980134374
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num22.weight_true | Size:torch.Size([]) | Values : 0.6569090282376854
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num23.weight_true | Size:torch.Size([]) | Values : -0.6430828077060753
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num24.weight_true | Size:torch.Size([]) | Values : -0.8096435788447566
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num25.weight_true | Size:torch.Size([]) | Values : 0.8998557455244269
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num26.weight_true | Size:torch.Size([]) | Values : 0.5491131455186499
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num27.weight_true | Size:torch.Size([]) | Values : 0.4378821695548113
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num28.weight_true | Size:torch.Size([]) | Values : -0.02832622611114279
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num29.weight_true | Size:torch.Size([]) | Values : 0.519022799149304
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num30.weight_true | Size:torch.Size([]) | Values : 1.4321169399064426
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num31.weight_true | Size:torch.Size([]) | Values : 0.8534491197033582
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num32.weight_true | Size:torch.Size([]) | Values : -1.4995147787829144
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num33.weight_true | Size:torch.Size([]) | Values : 0.8532124828164035
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num34.weight_true | Size:torch.Size([]) | Values : 0.41597023191715615
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num35.weight_true | Size:torch.Size([]) | Values : -0.06912895813764527
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num36.weight_true | Size:torch.Size([]) | Values : 0.7605672744656397
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num37.weight_true | Size:torch.Size([]) | Values : 0.26452275695456956
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num38.weight_true | Size:torch.Size([]) | Values : 0.40050941561081677
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num39.weight_true | Size:torch.Size([]) | Values : 0.7015078660909314
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num40.weight_true | Size:torch.Size([]) | Values : 0.21217889565545403
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num41.weight_true | Size:torch.Size([]) | Values : 1.214788707633012
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num42.weight_true | Size:torch.Size([]) | Values : -0.01739441601907441
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num43.weight_true | Size:torch.Size([]) | Values : -0.47700262272945454
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num44.weight_true | Size:torch.Size([]) | Values : -1.2009954919849755
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num45.weight_true | Size:torch.Size([]) | Values : -0.027357308441998823
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num46.weight_true | Size:torch.Size([]) | Values : 0.6638847516559846
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num47.weight_true | Size:torch.Size([]) | Values : 1.031192281243353
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num48.weight_true | Size:torch.Size([]) | Values : -0.8206264665555957
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num49.weight_true | Size:torch.Size([]) | Values : 1.605569342901635
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num50.weight_true | Size:torch.Size([]) | Values : -0.3584836098070855
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num51.weight_true | Size:torch.Size([]) | Values : -0.8005047763791986
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num52.weight_true | Size:torch.Size([]) | Values : -1.001613521371762
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num53.weight_true | Size:torch.Size([]) | Values : 0.09025299391978693
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num54.weight_true | Size:torch.Size([]) | Values : 1.1442963798367163
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num55.weight_true | Size:torch.Size([]) | Values : 1.7635694724751252
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num56.weight_true | Size:torch.Size([]) | Values : -0.30913272366785766
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num57.weight_true | Size:torch.Size([]) | Values : 0.5055567685331698
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num58.weight_true | Size:torch.Size([]) | Values : -0.21651343368373702
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num59.weight_true | Size:torch.Size([]) | Values : 0.4195160721325676
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num60.weight_true | Size:torch.Size([]) | Values : -0.26306613772542065
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num61.weight_true | Size:torch.Size([]) | Values : -0.02617352859312506
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num62.weight_true | Size:torch.Size([]) | Values : -0.5111922757634606
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num63.weight_true | Size:torch.Size([]) | Values : -2.3182686875118574
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num64.weight_true | Size:torch.Size([]) | Values : -1.082249146751168
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num65.weight_true | Size:torch.Size([]) | Values : 0.9083548921793037
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num66.weight_true | Size:torch.Size([]) | Values : -0.1637443554054731
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num67.weight_true | Size:torch.Size([]) | Values : -2.514566250912701
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num68.weight_true | Size:torch.Size([]) | Values : -0.408263664240429
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num69.weight_true | Size:torch.Size([]) | Values : 1.569955198070799
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num70.weight_true | Size:torch.Size([]) | Values : 0.8793714888753988
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num71.weight_true | Size:torch.Size([]) | Values : 1.339881564343839
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num72.weight_true | Size:torch.Size([]) | Values : 1.0219632350706922
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num73.weight_true | Size:torch.Size([]) | Values : -2.0516801787946304
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num74.weight_true | Size:torch.Size([]) | Values : -1.0669643840264422
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num75.weight_true | Size:torch.Size([]) | Values : 0.38742874396886995
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num76.weight_true | Size:torch.Size([]) | Values : 1.1473668696776547
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num77.weight_true | Size:torch.Size([]) | Values : -0.37430657634820746
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num78.weight_true | Size:torch.Size([]) | Values : -1.7197807530683158
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num79.weight_true | Size:torch.Size([]) | Values : 0.5127361571205702
#
# Layer:space_transform.rbf_seq1.rbf_unit_res2num80.weight_true | Size:torch.Size([]) | Values : -0.5772987416850932
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num0.weight_true | Size:torch.Size([]) | Values : -0.2550344235298067
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num1.weight_true | Size:torch.Size([]) | Values : 0.5681514792194229
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num2.weight_true | Size:torch.Size([]) | Values : -0.39515755909654215
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num3.weight_true | Size:torch.Size([]) | Values : 0.8219459342819598
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num4.weight_true | Size:torch.Size([]) | Values : -1.7332667824672947
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num5.weight_true | Size:torch.Size([]) | Values : 0.11358313470527556
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num6.weight_true | Size:torch.Size([]) | Values : -0.08950703345603597
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num7.weight_true | Size:torch.Size([]) | Values : -0.8175994317653892
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num8.weight_true | Size:torch.Size([]) | Values : -1.4809398518366936
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num9.weight_true | Size:torch.Size([]) | Values : -1.3679960280888384
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num10.weight_true | Size:torch.Size([]) | Values : 1.252967434852237
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num11.weight_true | Size:torch.Size([]) | Values : 0.7824614054665704
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num12.weight_true | Size:torch.Size([]) | Values : 0.7053770750100045
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num13.weight_true | Size:torch.Size([]) | Values : 0.47694353766657654
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num14.weight_true | Size:torch.Size([]) | Values : -0.4261494944387368
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num15.weight_true | Size:torch.Size([]) | Values : 0.9967098602867268
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num16.weight_true | Size:torch.Size([]) | Values : -0.11075912532061394
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num17.weight_true | Size:torch.Size([]) | Values : -0.42249300047681976
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num18.weight_true | Size:torch.Size([]) | Values : 1.268834660243432
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num19.weight_true | Size:torch.Size([]) | Values : 0.8799247893459952
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num20.weight_true | Size:torch.Size([]) | Values : 0.812703078836227
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num21.weight_true | Size:torch.Size([]) | Values : -0.3101580971149227
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num22.weight_true | Size:torch.Size([]) | Values : 0.561668175436392
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num23.weight_true | Size:torch.Size([]) | Values : 0.6868263461117108
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num24.weight_true | Size:torch.Size([]) | Values : -0.14108756936345793
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num25.weight_true | Size:torch.Size([]) | Values : 1.3801670082962025
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num26.weight_true | Size:torch.Size([]) | Values : -0.3489516908629233
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num27.weight_true | Size:torch.Size([]) | Values : -0.331826978004788
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num28.weight_true | Size:torch.Size([]) | Values : 0.7608478681969879
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num29.weight_true | Size:torch.Size([]) | Values : -1.5311421877444031
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num30.weight_true | Size:torch.Size([]) | Values : 1.297943175785907
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num31.weight_true | Size:torch.Size([]) | Values : -1.2952547992417216
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num32.weight_true | Size:torch.Size([]) | Values : 0.3700662813467664
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num33.weight_true | Size:torch.Size([]) | Values : -1.0111916393255345
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num34.weight_true | Size:torch.Size([]) | Values : -0.41323438372939303
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num35.weight_true | Size:torch.Size([]) | Values : 2.1837446434919388
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num36.weight_true | Size:torch.Size([]) | Values : 0.4012705085400272
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num37.weight_true | Size:torch.Size([]) | Values : 0.8955888960607362
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num38.weight_true | Size:torch.Size([]) | Values : 1.0981761340244716
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num39.weight_true | Size:torch.Size([]) | Values : -1.405571430272332
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num40.weight_true | Size:torch.Size([]) | Values : 1.0974900409790045
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num41.weight_true | Size:torch.Size([]) | Values : -1.3809538236520305
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num42.weight_true | Size:torch.Size([]) | Values : 0.6861870855355753
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num43.weight_true | Size:torch.Size([]) | Values : -0.27882508772264625
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num44.weight_true | Size:torch.Size([]) | Values : 0.38067516237076754
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num45.weight_true | Size:torch.Size([]) | Values : -0.8297994542302318
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num46.weight_true | Size:torch.Size([]) | Values : 1.8869021073065064
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num47.weight_true | Size:torch.Size([]) | Values : -1.3170391218968043
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num48.weight_true | Size:torch.Size([]) | Values : 1.0507888995780894
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num49.weight_true | Size:torch.Size([]) | Values : -1.2445507988089615
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num50.weight_true | Size:torch.Size([]) | Values : -0.6629074792008289
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num51.weight_true | Size:torch.Size([]) | Values : 0.04464767436476477
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num52.weight_true | Size:torch.Size([]) | Values : -0.2246911018694529
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num53.weight_true | Size:torch.Size([]) | Values : 0.34933488898020304
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num54.weight_true | Size:torch.Size([]) | Values : 1.3095430404100061
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num55.weight_true | Size:torch.Size([]) | Values : 1.4807863840238578
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num56.weight_true | Size:torch.Size([]) | Values : 0.5407191754707614
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num57.weight_true | Size:torch.Size([]) | Values : -0.047196957545493134
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num58.weight_true | Size:torch.Size([]) | Values : -0.3590970847499201
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num59.weight_true | Size:torch.Size([]) | Values : -0.396545851587416
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num60.weight_true | Size:torch.Size([]) | Values : 0.17275733981872898
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num61.weight_true | Size:torch.Size([]) | Values : 3.0227365826990193
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num62.weight_true | Size:torch.Size([]) | Values : -0.12353520885505076
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num63.weight_true | Size:torch.Size([]) | Values : 0.9736584228481414
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num64.weight_true | Size:torch.Size([]) | Values : -0.001245906728032514
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num65.weight_true | Size:torch.Size([]) | Values : -0.684752917620747
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num66.weight_true | Size:torch.Size([]) | Values : 0.4252433523027178
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num67.weight_true | Size:torch.Size([]) | Values : -0.9323044179992723
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num68.weight_true | Size:torch.Size([]) | Values : 0.8797397437178319
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num69.weight_true | Size:torch.Size([]) | Values : -0.4640862180918858
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num70.weight_true | Size:torch.Size([]) | Values : 1.3913091026420454
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num71.weight_true | Size:torch.Size([]) | Values : 0.9967846251000224
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num72.weight_true | Size:torch.Size([]) | Values : 0.1296139553228334
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num73.weight_true | Size:torch.Size([]) | Values : -0.8783002647895536
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num74.weight_true | Size:torch.Size([]) | Values : -0.12436412224359573
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num75.weight_true | Size:torch.Size([]) | Values : 0.10921559377825067
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num76.weight_true | Size:torch.Size([]) | Values : -0.7482545242333215
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num77.weight_true | Size:torch.Size([]) | Values : 0.31830816813973467
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num78.weight_true | Size:torch.Size([]) | Values : -0.9437126281463258
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num79.weight_true | Size:torch.Size([]) | Values : 0.8110812087098848
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num80.weight_true | Size:torch.Size([]) | Values : -0.03787129475362559
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num81.weight_true | Size:torch.Size([]) | Values : 0.47990071314936067
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num82.weight_true | Size:torch.Size([]) | Values : -0.5240292221793306
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num83.weight_true | Size:torch.Size([]) | Values : 0.6035851044558257
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num84.weight_true | Size:torch.Size([]) | Values : -1.9215578594048655
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num85.weight_true | Size:torch.Size([]) | Values : -0.1026088560080952
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num86.weight_true | Size:torch.Size([]) | Values : 0.40919624424887585
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num87.weight_true | Size:torch.Size([]) | Values : 0.4888305030790696
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num88.weight_true | Size:torch.Size([]) | Values : -0.10328861150561408
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num89.weight_true | Size:torch.Size([]) | Values : 0.422262646016548
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num90.weight_true | Size:torch.Size([]) | Values : -1.8364276269222768
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num91.weight_true | Size:torch.Size([]) | Values : -0.1892121112832823
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num92.weight_true | Size:torch.Size([]) | Values : 0.8073062328439525
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num93.weight_true | Size:torch.Size([]) | Values : 0.5883528920536377
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num94.weight_true | Size:torch.Size([]) | Values : -0.33878956297555135
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num95.weight_true | Size:torch.Size([]) | Values : 1.6677042321252498
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num96.weight_true | Size:torch.Size([]) | Values : -0.790833901987145
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num97.weight_true | Size:torch.Size([]) | Values : -0.13505733123105515
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num98.weight_true | Size:torch.Size([]) | Values : 0.6790859948041915
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num99.weight_true | Size:torch.Size([]) | Values : 0.7269106706553876
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num100.weight_true | Size:torch.Size([]) | Values : 0.3194476893017591
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num101.weight_true | Size:torch.Size([]) | Values : 0.7894047221598711
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num102.weight_true | Size:torch.Size([]) | Values : -0.25510858338263726
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num103.weight_true | Size:torch.Size([]) | Values : -0.14589588766295983
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num104.weight_true | Size:torch.Size([]) | Values : -0.7220437316199069
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num105.weight_true | Size:torch.Size([]) | Values : -1.2598288926261834
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num106.weight_true | Size:torch.Size([]) | Values : -1.3429358553905895
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num107.weight_true | Size:torch.Size([]) | Values : 0.7971758923192501
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num108.weight_true | Size:torch.Size([]) | Values : 1.1269737422439563
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num109.weight_true | Size:torch.Size([]) | Values : -2.9401273311591516
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num110.weight_true | Size:torch.Size([]) | Values : -0.17880459687310463
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num111.weight_true | Size:torch.Size([]) | Values : 0.7399748765289915
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num112.weight_true | Size:torch.Size([]) | Values : -0.2667930163473456
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num113.weight_true | Size:torch.Size([]) | Values : -1.911951292957661
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num114.weight_true | Size:torch.Size([]) | Values : 1.7455353740702801
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num115.weight_true | Size:torch.Size([]) | Values : 0.5122451555607811
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num116.weight_true | Size:torch.Size([]) | Values : 2.117810042520654
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num117.weight_true | Size:torch.Size([]) | Values : -0.28637833156319814
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num118.weight_true | Size:torch.Size([]) | Values : 0.6554997829058496
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num119.weight_true | Size:torch.Size([]) | Values : -0.3293063200952813
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num120.weight_true | Size:torch.Size([]) | Values : -1.6400412840185576
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num121.weight_true | Size:torch.Size([]) | Values : 2.287828587625331
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num122.weight_true | Size:torch.Size([]) | Values : -0.9507271182012236
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num123.weight_true | Size:torch.Size([]) | Values : 0.21294773593446834
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num124.weight_true | Size:torch.Size([]) | Values : 0.33243236767513157
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num125.weight_true | Size:torch.Size([]) | Values : 0.9717782551132721
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num126.weight_true | Size:torch.Size([]) | Values : -0.6589653058243143
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num127.weight_true | Size:torch.Size([]) | Values : -1.0945094282712113
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num128.weight_true | Size:torch.Size([]) | Values : -0.3868789888157034
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num129.weight_true | Size:torch.Size([]) | Values : -0.40651666760566874
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num130.weight_true | Size:torch.Size([]) | Values : -1.0712846949001722
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num131.weight_true | Size:torch.Size([]) | Values : -1.8045869345941519
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num132.weight_true | Size:torch.Size([]) | Values : 0.014061612372488964
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num133.weight_true | Size:torch.Size([]) | Values : 0.45371185302663825
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num134.weight_true | Size:torch.Size([]) | Values : 0.4113466615046816
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num135.weight_true | Size:torch.Size([]) | Values : 1.9421740747330938
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num136.weight_true | Size:torch.Size([]) | Values : 1.5839551085451593
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num137.weight_true | Size:torch.Size([]) | Values : -0.09614615667745206
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num138.weight_true | Size:torch.Size([]) | Values : 1.4675045412590464
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num139.weight_true | Size:torch.Size([]) | Values : -1.138202405424195
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num140.weight_true | Size:torch.Size([]) | Values : -0.05933105840398916
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num141.weight_true | Size:torch.Size([]) | Values : 0.40145441116292147
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num142.weight_true | Size:torch.Size([]) | Values : 2.199779422466506
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num143.weight_true | Size:torch.Size([]) | Values : 0.8058246676424804
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num144.weight_true | Size:torch.Size([]) | Values : 0.14994479863336257
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num145.weight_true | Size:torch.Size([]) | Values : -0.5618041763773522
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num146.weight_true | Size:torch.Size([]) | Values : -0.5599293935767254
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num147.weight_true | Size:torch.Size([]) | Values : -0.8383042034163911
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num148.weight_true | Size:torch.Size([]) | Values : -0.06618618228326989
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num149.weight_true | Size:torch.Size([]) | Values : -0.09615731908978485
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num150.weight_true | Size:torch.Size([]) | Values : 1.1837646424955406
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num151.weight_true | Size:torch.Size([]) | Values : -0.3549034016250407
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num152.weight_true | Size:torch.Size([]) | Values : 0.04018903307145527
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num153.weight_true | Size:torch.Size([]) | Values : -0.8017707233457972
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num154.weight_true | Size:torch.Size([]) | Values : -1.2172190225556183
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num155.weight_true | Size:torch.Size([]) | Values : -0.24391072308067724
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num156.weight_true | Size:torch.Size([]) | Values : 0.44012981557547254
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num157.weight_true | Size:torch.Size([]) | Values : 0.26884667368986936
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num158.weight_true | Size:torch.Size([]) | Values : -0.14031348383476736
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num159.weight_true | Size:torch.Size([]) | Values : -0.2378112255920403
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num160.weight_true | Size:torch.Size([]) | Values : 1.0371440858539935
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num161.weight_true | Size:torch.Size([]) | Values : -0.6131885461466398
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num162.weight_true | Size:torch.Size([]) | Values : -1.35351596835675
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num163.weight_true | Size:torch.Size([]) | Values : -0.7033031767201289
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num164.weight_true | Size:torch.Size([]) | Values : 0.2828701095860903
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num165.weight_true | Size:torch.Size([]) | Values : 0.7550000497611952
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num166.weight_true | Size:torch.Size([]) | Values : 1.9673786075219488
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num167.weight_true | Size:torch.Size([]) | Values : 1.0857357966979877
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num168.weight_true | Size:torch.Size([]) | Values : 0.3230286470323859
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num169.weight_true | Size:torch.Size([]) | Values : 0.9405867531475274
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num170.weight_true | Size:torch.Size([]) | Values : -0.052074234154399185
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num171.weight_true | Size:torch.Size([]) | Values : -0.034723948213558245
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num172.weight_true | Size:torch.Size([]) | Values : -2.1240621245831166
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num173.weight_true | Size:torch.Size([]) | Values : 0.8481486685171851
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num174.weight_true | Size:torch.Size([]) | Values : 1.1657590627102739
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num175.weight_true | Size:torch.Size([]) | Values : 0.570440775544197
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num176.weight_true | Size:torch.Size([]) | Values : -0.7917630544686044
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num177.weight_true | Size:torch.Size([]) | Values : 0.4821899618120019
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num178.weight_true | Size:torch.Size([]) | Values : 0.2261035252839554
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num179.weight_true | Size:torch.Size([]) | Values : -0.1315989428525528
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num180.weight_true | Size:torch.Size([]) | Values : -0.5946685966122705
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num181.weight_true | Size:torch.Size([]) | Values : 0.8771216975610265
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num182.weight_true | Size:torch.Size([]) | Values : 0.7819297065024048
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num183.weight_true | Size:torch.Size([]) | Values : 1.7302062511216776
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num184.weight_true | Size:torch.Size([]) | Values : -0.007989954968387995
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num185.weight_true | Size:torch.Size([]) | Values : 1.958920208769019
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num186.weight_true | Size:torch.Size([]) | Values : 2.362647634732452
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num187.weight_true | Size:torch.Size([]) | Values : -0.003107481857492062
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num188.weight_true | Size:torch.Size([]) | Values : 0.2240571266404605
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num189.weight_true | Size:torch.Size([]) | Values : 1.4020790338399258
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num190.weight_true | Size:torch.Size([]) | Values : 2.6128111613703826
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num191.weight_true | Size:torch.Size([]) | Values : -0.026110639185002064
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num192.weight_true | Size:torch.Size([]) | Values : 0.12256621783267221
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num193.weight_true | Size:torch.Size([]) | Values : 2.1573172247562624
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num194.weight_true | Size:torch.Size([]) | Values : -0.3291665451425158
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num195.weight_true | Size:torch.Size([]) | Values : -0.08947274309534971
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num196.weight_true | Size:torch.Size([]) | Values : 0.6151131205933982
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num197.weight_true | Size:torch.Size([]) | Values : 0.04585688371377378
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num198.weight_true | Size:torch.Size([]) | Values : 1.5776933112237017
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num199.weight_true | Size:torch.Size([]) | Values : 0.8612380848374293
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num200.weight_true | Size:torch.Size([]) | Values : -0.019645077665069004
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num201.weight_true | Size:torch.Size([]) | Values : -0.10519113143994549
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num202.weight_true | Size:torch.Size([]) | Values : -0.9268619834932372
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num203.weight_true | Size:torch.Size([]) | Values : -1.080846045860547
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num204.weight_true | Size:torch.Size([]) | Values : 1.0181533137095882
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num205.weight_true | Size:torch.Size([]) | Values : 0.771228223930689
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num206.weight_true | Size:torch.Size([]) | Values : 1.1984784301337739
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num207.weight_true | Size:torch.Size([]) | Values : -1.5002329640893952
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num208.weight_true | Size:torch.Size([]) | Values : -2.547734104464196
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num209.weight_true | Size:torch.Size([]) | Values : -0.6039990292988505
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num210.weight_true | Size:torch.Size([]) | Values : -1.3322774730252127
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num211.weight_true | Size:torch.Size([]) | Values : -1.7511472327885678
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num212.weight_true | Size:torch.Size([]) | Values : 1.220530204606958
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num213.weight_true | Size:torch.Size([]) | Values : 0.8802557440434743
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num214.weight_true | Size:torch.Size([]) | Values : -0.7213060808301062
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num215.weight_true | Size:torch.Size([]) | Values : 0.04482314051720164
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num216.weight_true | Size:torch.Size([]) | Values : 0.7246897486729704
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num217.weight_true | Size:torch.Size([]) | Values : -1.3184585945237601
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num218.weight_true | Size:torch.Size([]) | Values : -0.21066411837130666
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num219.weight_true | Size:torch.Size([]) | Values : -0.7240379876296029
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num220.weight_true | Size:torch.Size([]) | Values : -0.33084965905384206
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num221.weight_true | Size:torch.Size([]) | Values : -2.8056330635452875
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num222.weight_true | Size:torch.Size([]) | Values : -0.11877253020499802
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num223.weight_true | Size:torch.Size([]) | Values : 0.6182297177230416
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num224.weight_true | Size:torch.Size([]) | Values : -1.166904952786051
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num225.weight_true | Size:torch.Size([]) | Values : 0.7305771435413646
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num226.weight_true | Size:torch.Size([]) | Values : 1.0557069109393349
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num227.weight_true | Size:torch.Size([]) | Values : -0.24658817401560695
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num228.weight_true | Size:torch.Size([]) | Values : 1.2127447479201872
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num229.weight_true | Size:torch.Size([]) | Values : -1.0903997486228845
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num230.weight_true | Size:torch.Size([]) | Values : -1.3122891947824995
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num231.weight_true | Size:torch.Size([]) | Values : -0.6553148907850592
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num232.weight_true | Size:torch.Size([]) | Values : -0.6541988223031916
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num233.weight_true | Size:torch.Size([]) | Values : -0.06810880085969685
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num234.weight_true | Size:torch.Size([]) | Values : -1.3044944425186051
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num235.weight_true | Size:torch.Size([]) | Values : 0.2628919717912474
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num236.weight_true | Size:torch.Size([]) | Values : 0.6099011123999246
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num237.weight_true | Size:torch.Size([]) | Values : -0.12317166672508574
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num238.weight_true | Size:torch.Size([]) | Values : -1.6012085506715654
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num239.weight_true | Size:torch.Size([]) | Values : 1.4434780159600953
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num240.weight_true | Size:torch.Size([]) | Values : -0.8165521007467924
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num241.weight_true | Size:torch.Size([]) | Values : -1.7726625422888695
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num242.weight_true | Size:torch.Size([]) | Values : 1.6781654948229083
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num243.weight_true | Size:torch.Size([]) | Values : 1.1316210911435036
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num244.weight_true | Size:torch.Size([]) | Values : 0.9189059500860987
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num245.weight_true | Size:torch.Size([]) | Values : 0.23708806380953942
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num246.weight_true | Size:torch.Size([]) | Values : -0.4554728227965482
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num247.weight_true | Size:torch.Size([]) | Values : -0.25100986605863435
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num248.weight_true | Size:torch.Size([]) | Values : 0.3639080977435356
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num249.weight_true | Size:torch.Size([]) | Values : 0.282320526473687
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num250.weight_true | Size:torch.Size([]) | Values : -2.035336759326079
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num251.weight_true | Size:torch.Size([]) | Values : 0.059088248738004966
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num252.weight_true | Size:torch.Size([]) | Values : 0.5142002392771079
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num253.weight_true | Size:torch.Size([]) | Values : -0.5459098028408919
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num254.weight_true | Size:torch.Size([]) | Values : 0.9534403331789632
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num255.weight_true | Size:torch.Size([]) | Values : 0.6409997959841202
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num256.weight_true | Size:torch.Size([]) | Values : 0.0021466248569063503
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num257.weight_true | Size:torch.Size([]) | Values : 0.5330469795147504
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num258.weight_true | Size:torch.Size([]) | Values : 0.34010037399653364
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num259.weight_true | Size:torch.Size([]) | Values : -0.3947086825973128
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num260.weight_true | Size:torch.Size([]) | Values : 0.2254904685971003
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num261.weight_true | Size:torch.Size([]) | Values : 0.6344938770808269
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num262.weight_true | Size:torch.Size([]) | Values : 0.794878930449429
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num263.weight_true | Size:torch.Size([]) | Values : 0.060192242436576865
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num264.weight_true | Size:torch.Size([]) | Values : -1.5127020036756984
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num265.weight_true | Size:torch.Size([]) | Values : -0.035988505695819066
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num266.weight_true | Size:torch.Size([]) | Values : 0.30785503647472257
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num267.weight_true | Size:torch.Size([]) | Values : -0.786909777566097
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num268.weight_true | Size:torch.Size([]) | Values : 0.23894305250305814
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num269.weight_true | Size:torch.Size([]) | Values : -1.2031128717620145
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num270.weight_true | Size:torch.Size([]) | Values : -0.7466578009501712
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num271.weight_true | Size:torch.Size([]) | Values : -0.7903262638103059
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num272.weight_true | Size:torch.Size([]) | Values : -0.9682311104867037
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num273.weight_true | Size:torch.Size([]) | Values : -0.7814586622943019
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num274.weight_true | Size:torch.Size([]) | Values : -1.9398528158822257
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num275.weight_true | Size:torch.Size([]) | Values : 0.11483689511164712
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num276.weight_true | Size:torch.Size([]) | Values : 1.019476290381919
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num277.weight_true | Size:torch.Size([]) | Values : -1.2585905041158638
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num278.weight_true | Size:torch.Size([]) | Values : 0.21400950720388517
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num279.weight_true | Size:torch.Size([]) | Values : 2.2783725965576136
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num280.weight_true | Size:torch.Size([]) | Values : 0.3066952325255262
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num281.weight_true | Size:torch.Size([]) | Values : -2.16184087203019
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num282.weight_true | Size:torch.Size([]) | Values : 1.2901389807126888
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num283.weight_true | Size:torch.Size([]) | Values : 0.7214957700856081
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num284.weight_true | Size:torch.Size([]) | Values : 1.1258116294797218
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num285.weight_true | Size:torch.Size([]) | Values : 0.1791298771468464
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num286.weight_true | Size:torch.Size([]) | Values : -0.8262999572263097
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num287.weight_true | Size:torch.Size([]) | Values : 0.606465068207747
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num288.weight_true | Size:torch.Size([]) | Values : -0.6151897687379747
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num289.weight_true | Size:torch.Size([]) | Values : -1.4621829180848978
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num290.weight_true | Size:torch.Size([]) | Values : -0.012220226150457307
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num291.weight_true | Size:torch.Size([]) | Values : 1.4845739962469582
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num292.weight_true | Size:torch.Size([]) | Values : -0.21457670834572026
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num293.weight_true | Size:torch.Size([]) | Values : 0.2918915640824002
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num294.weight_true | Size:torch.Size([]) | Values : 1.114938682378627
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num295.weight_true | Size:torch.Size([]) | Values : 0.4228519332935661
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num296.weight_true | Size:torch.Size([]) | Values : -1.3330675782316679
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num297.weight_true | Size:torch.Size([]) | Values : -0.40889130408542745
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num298.weight_true | Size:torch.Size([]) | Values : 1.0160317894643767
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num299.weight_true | Size:torch.Size([]) | Values : 0.06992500936325861
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num300.weight_true | Size:torch.Size([]) | Values : 0.8171741022846065
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num301.weight_true | Size:torch.Size([]) | Values : -0.2708419051728486
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num302.weight_true | Size:torch.Size([]) | Values : -1.529824103094857
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num303.weight_true | Size:torch.Size([]) | Values : -0.7791357905828485
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num304.weight_true | Size:torch.Size([]) | Values : -0.7209642723613436
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num305.weight_true | Size:torch.Size([]) | Values : -1.2481864769009776
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num306.weight_true | Size:torch.Size([]) | Values : 0.12152065778684354
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num307.weight_true | Size:torch.Size([]) | Values : 2.1238962918811737
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num308.weight_true | Size:torch.Size([]) | Values : -1.6091204394532452
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num309.weight_true | Size:torch.Size([]) | Values : 1.5748310821849696
#
# ...
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num599.weight_true | Size:torch.Size([]) | Values : 1.234268608196137
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num600.weight_true | Size:torch.Size([]) | Values : 0.47427655982933664
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num601.weight_true | Size:torch.Size([]) | Values : 0.737069087192482
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num602.weight_true | Size:torch.Size([]) | Values : 0.1937005031038981
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num603.weight_true | Size:torch.Size([]) | Values : -0.991909642950864
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num604.weight_true | Size:torch.Size([]) | Values : -0.6961821518896024
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num605.weight_true | Size:torch.Size([]) | Values : 1.4215310320345402
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num606.weight_true | Size:torch.Size([]) | Values : -1.2602442500463988
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num607.weight_true | Size:torch.Size([]) | Values : 0.5319543312539963
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num608.weight_true | Size:torch.Size([]) | Values : -0.1510963167199609
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num609.weight_true | Size:torch.Size([]) | Values : -1.3884784773848413
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num610.weight_true | Size:torch.Size([]) | Values : 2.132469917545799
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num611.weight_true | Size:torch.Size([]) | Values : -0.2079341240189646
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num612.weight_true | Size:torch.Size([]) | Values : -0.5918266649082096
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num613.weight_true | Size:torch.Size([]) | Values : 0.26766562625353807
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num614.weight_true | Size:torch.Size([]) | Values : 0.12425462213442269
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num615.weight_true | Size:torch.Size([]) | Values : 0.2235193361769486
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num616.weight_true | Size:torch.Size([]) | Values : 0.9143023328120715
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num617.weight_true | Size:torch.Size([]) | Values : -0.013198464535467792
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num618.weight_true | Size:torch.Size([]) | Values : -0.00683060738923358
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num619.weight_true | Size:torch.Size([]) | Values : 0.3222911885711662
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num620.weight_true | Size:torch.Size([]) | Values : -0.3071710965257441
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num621.weight_true | Size:torch.Size([]) | Values : 0.5316475055626569
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num622.weight_true | Size:torch.Size([]) | Values : 1.3328688670201898
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num623.weight_true | Size:torch.Size([]) | Values : -0.36696228975094763
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num624.weight_true | Size:torch.Size([]) | Values : -0.36401751615325595
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num625.weight_true | Size:torch.Size([]) | Values : -0.9150005762958249
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num626.weight_true | Size:torch.Size([]) | Values : -0.12950057388049638
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num627.weight_true | Size:torch.Size([]) | Values : 1.2513868208221683
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num628.weight_true | Size:torch.Size([]) | Values : 0.13140546263930436
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num629.weight_true | Size:torch.Size([]) | Values : 0.09115467441623654
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num630.weight_true | Size:torch.Size([]) | Values : -0.8651987460858416
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num631.weight_true | Size:torch.Size([]) | Values : -0.8725815761999228
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num632.weight_true | Size:torch.Size([]) | Values : 1.680149984077433
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num633.weight_true | Size:torch.Size([]) | Values : 0.3168811775446224
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num634.weight_true | Size:torch.Size([]) | Values : 0.7858374975259604
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num635.weight_true | Size:torch.Size([]) | Values : -0.2852594115656043
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num636.weight_true | Size:torch.Size([]) | Values : 1.1116729826458898
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num637.weight_true | Size:torch.Size([]) | Values : -1.0090967133089914
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num638.weight_true | Size:torch.Size([]) | Values : -1.0657572440087115
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num639.weight_true | Size:torch.Size([]) | Values : 0.29038839572734043
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num640.weight_true | Size:torch.Size([]) | Values : 0.3931412603606916
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num641.weight_true | Size:torch.Size([]) | Values : 0.5679648619035483
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num642.weight_true | Size:torch.Size([]) | Values : -0.21545966542282113
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num643.weight_true | Size:torch.Size([]) | Values : 0.03350750166101054
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num644.weight_true | Size:torch.Size([]) | Values : 0.5005879280595761
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num645.weight_true | Size:torch.Size([]) | Values : 0.03963370811796505
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num646.weight_true | Size:torch.Size([]) | Values : 1.1659798420086716
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num647.weight_true | Size:torch.Size([]) | Values : -0.7367019924275382
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num648.weight_true | Size:torch.Size([]) | Values : -0.9656919994608489
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num649.weight_true | Size:torch.Size([]) | Values : 0.10253979088394571
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num650.weight_true | Size:torch.Size([]) | Values : 1.3074147921506123
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num651.weight_true | Size:torch.Size([]) | Values : 1.367018682319893
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num652.weight_true | Size:torch.Size([]) | Values : -0.6532350262645944
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num653.weight_true | Size:torch.Size([]) | Values : 0.31820668930324836
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num654.weight_true | Size:torch.Size([]) | Values : -1.1117279313062574
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num655.weight_true | Size:torch.Size([]) | Values : 2.0735872878382087
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num656.weight_true | Size:torch.Size([]) | Values : -2.006045200777112
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num657.weight_true | Size:torch.Size([]) | Values : -1.7048036072444064
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num658.weight_true | Size:torch.Size([]) | Values : 1.1863978672598845
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num659.weight_true | Size:torch.Size([]) | Values : -0.26231439937255163
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num660.weight_true | Size:torch.Size([]) | Values : -1.6859650740084786
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num661.weight_true | Size:torch.Size([]) | Values : -0.8404059610715762
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num662.weight_true | Size:torch.Size([]) | Values : 0.522535026792664
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num663.weight_true | Size:torch.Size([]) | Values : 1.525975710734226
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num664.weight_true | Size:torch.Size([]) | Values : -0.2887167927234766
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num665.weight_true | Size:torch.Size([]) | Values : -0.21642922327999842
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num666.weight_true | Size:torch.Size([]) | Values : -0.28296253222569195
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num667.weight_true | Size:torch.Size([]) | Values : -0.6639505934557585
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num668.weight_true | Size:torch.Size([]) | Values : -0.0031877173751626623
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num669.weight_true | Size:torch.Size([]) | Values : -0.2114013350380057
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num670.weight_true | Size:torch.Size([]) | Values : 0.49027326015418626
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num671.weight_true | Size:torch.Size([]) | Values : -0.6201846339941677
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num672.weight_true | Size:torch.Size([]) | Values : -1.8844447597670062
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num673.weight_true | Size:torch.Size([]) | Values : -0.67785736376965
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num674.weight_true | Size:torch.Size([]) | Values : 0.28419567501748394
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num675.weight_true | Size:torch.Size([]) | Values : -1.2465630322936
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num676.weight_true | Size:torch.Size([]) | Values : -1.192792004094941
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num677.weight_true | Size:torch.Size([]) | Values : -0.7040235786319665
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num678.weight_true | Size:torch.Size([]) | Values : -0.36259172076946755
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num679.weight_true | Size:torch.Size([]) | Values : 1.6044428696868396
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num680.weight_true | Size:torch.Size([]) | Values : 0.18296868303753264
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num681.weight_true | Size:torch.Size([]) | Values : 0.7108223731552616
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num682.weight_true | Size:torch.Size([]) | Values : 0.0130434676061664
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num683.weight_true | Size:torch.Size([]) | Values : -1.1382412124228265
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num684.weight_true | Size:torch.Size([]) | Values : -0.8782491537033958
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num685.weight_true | Size:torch.Size([]) | Values : 1.0742125704610697
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num686.weight_true | Size:torch.Size([]) | Values : 1.1654484605180113
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num687.weight_true | Size:torch.Size([]) | Values : 0.16493568203941963
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num688.weight_true | Size:torch.Size([]) | Values : -0.12537920375436748
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num689.weight_true | Size:torch.Size([]) | Values : 0.8689155255042911
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num690.weight_true | Size:torch.Size([]) | Values : 0.92817800673168
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num691.weight_true | Size:torch.Size([]) | Values : -0.40170308721622194
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num692.weight_true | Size:torch.Size([]) | Values : -1.0687282922597143
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num693.weight_true | Size:torch.Size([]) | Values : 0.126264695879991
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num694.weight_true | Size:torch.Size([]) | Values : -1.1167404719894893
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num695.weight_true | Size:torch.Size([]) | Values : 1.610888772754143
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num696.weight_true | Size:torch.Size([]) | Values : 2.2751072375894057
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num697.weight_true | Size:torch.Size([]) | Values : 0.3601253241830555
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num698.weight_true | Size:torch.Size([]) | Values : 1.416410426734023
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num699.weight_true | Size:torch.Size([]) | Values : 1.525864965547287
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num700.weight_true | Size:torch.Size([]) | Values : -0.694052187850227
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num701.weight_true | Size:torch.Size([]) | Values : -1.6159433333759934
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num702.weight_true | Size:torch.Size([]) | Values : 0.8781594029298475
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num703.weight_true | Size:torch.Size([]) | Values : -0.5997529380836019
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num704.weight_true | Size:torch.Size([]) | Values : -1.7172866523177037
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num705.weight_true | Size:torch.Size([]) | Values : -0.6056446010397315
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num706.weight_true | Size:torch.Size([]) | Values : -0.3478650119595465
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num707.weight_true | Size:torch.Size([]) | Values : -1.0338552164180326
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num708.weight_true | Size:torch.Size([]) | Values : -3.37898379655528
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num709.weight_true | Size:torch.Size([]) | Values : 0.7531679272856219
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num710.weight_true | Size:torch.Size([]) | Values : 0.2778431726410156
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num711.weight_true | Size:torch.Size([]) | Values : -0.4256287000285098
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num712.weight_true | Size:torch.Size([]) | Values : 0.16993001904882699
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num713.weight_true | Size:torch.Size([]) | Values : 0.8648581017218087
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num714.weight_true | Size:torch.Size([]) | Values : 1.7165723772615402
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num715.weight_true | Size:torch.Size([]) | Values : -0.06295221803885809
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num716.weight_true | Size:torch.Size([]) | Values : 2.2271202101149044
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num717.weight_true | Size:torch.Size([]) | Values : 1.292634407994569
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num718.weight_true | Size:torch.Size([]) | Values : -0.39398329116365394
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num719.weight_true | Size:torch.Size([]) | Values : -1.1948569569003307
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num720.weight_true | Size:torch.Size([]) | Values : 1.512148297662398
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num721.weight_true | Size:torch.Size([]) | Values : -0.09889310427710207
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num722.weight_true | Size:torch.Size([]) | Values : 0.20348669117373602
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num723.weight_true | Size:torch.Size([]) | Values : -1.6924720371050133
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num724.weight_true | Size:torch.Size([]) | Values : -2.5926512270037123
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num725.weight_true | Size:torch.Size([]) | Values : -1.2867515894171597
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num726.weight_true | Size:torch.Size([]) | Values : 0.5117290965075273
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num727.weight_true | Size:torch.Size([]) | Values : -0.2811529924441212
#
# Layer:space_transform.rbf_seq2.rbf_unit_res3num728.weight_true | Size:torch.Size([]) | Values : -0.055026551243073256
#
# Layer:space_transform.mobius.a1Re | Size:torch.Size([]) | Values : 0.28685964244239737
#
# Layer:space_transform.mobius.a2Re | Size:torch.Size([]) | Values : -0.07266296957624045
#
# Layer:space_transform.mobius.a3Re | Size:torch.Size([]) | Values : -0.5282579750883261
#
# Layer:space_transform.mobius.a4Re | Size:torch.Size([]) | Values : -0.8453573462546867
#
# Layer:space_transform.mobius.a1Im | Size:torch.Size([]) | Values : -0.25607404340429996
#
# Layer:space_transform.mobius.a2Im | Size:torch.Size([]) | Values : -0.48007538108075837
#
# Layer:space_transform.mobius.a3Im | Size:torch.Size([]) | Values : 0.5474985328654014
#
# Layer:space_transform.mobius.a4Im | Size:torch.Size([]) | Values : -1.2032016264174612

# %%
# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, gp_model)


def train(epoch):
    gp_model.train()
    likelihood.train()

    for j in range(epoch):
        # Zero backprop gradients
        optimizer.zero_grad()
        # Get output from model
        output = gp_model(train_X_tensor)
        # Calc loss and backprop derivatives
        loss = -mll(output, train_y_tensor)
        loss.backward()

        optimizer.step()
    writer.add_scalar("loss", loss.item(), i)
    writer.add_scalar(
        "length_scale1", gp_model.covar_module.base_kernel.lengthscale.item(), i
    )
    writer.add_scalar("output_scale1", gp_model.covar_module.outputscale.item(), i)
    #             writer.add_scalar("offset0", gp_model.offset[0, 0].item(), i)
    #             writer.add_scalar("offset1", gp_model.offset[0, 1].item(), i)
    writer.add_scalar("output_scale", gp_model.covar_module2.outputscale.item(), i)
    #             writer.add_scalar("offset0", gp_model.offset[0, 0].item(), i)
    #             writer.add_scalar("offset1", gp_model.offset[0, 1].item(), i)
    writer.add_scalar(
        "length_scale",
        gp_model.covar_module2.base_kernel.lengthscale.item(),
        i,
    )


#             writer.add_scalar(
#                 "output_scale", gp_model.covar_module2.outputscale.item(), i
#             )


def test():
    likelihood.eval()
    gp_model.eval()
    observed_pred = gp_model(test_X_tensor)
    mean = observed_pred.mean.detach() + train_y_mean
    mape = MAPE(test_y_tensor.cpu().numpy(), mean.cpu().numpy())
    writer.add_scalar(
        "mape",
        mape,
        i,
    )
    return mape

# %%
# Use the adam optimizer
optimizer = torch.optim.Adam(
    [
        #         {"params": gp_model.offset, "lr": 0.1},
        {"params": gp_model.space_transform.parameters()},
        {"params": gp_model.covar_module.parameters()},
        #         {"params": gp_model.covar_module2.raw_outputscale},
        {"params": gp_model.covar_module2.parameters()},
        #         {"params": gp_model.mean_module.parameters()},
        #         {"params": gp_model.likelihood.parameters()},
    ],
    lr=0.01,
)
gp_model.w1 = 1
gp_model.w2 = 1

# %%
now = datetime.now()
log_dir = "logs/warpgp/" + now.strftime("%Y%m%d-%H%M%S") + "/"
# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter(log_dir)

mape_store = 1000
iterator = tqdm.notebook.tqdm(range(10000))
for i in iterator:
    train(10)
    mape = test()
    if mape < mape_store:
        mape_store = mape
        state_dict = gp_model.state_dict()
        likelihood_state_dict = likelihood.state_dict()
        torch.save(
            {"model": state_dict, "likelihood": likelihood_state_dict}, "checkpoint.dat"
        )
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4fab3d045b9d> in <module>
#       7 iterator = tqdm.notebook.tqdm(range(10000))
#       8 for i in iterator:
# ----> 9     train(10)
#      10     mape = test()
#      11     if mape < mape_store:
#
# <ipython-input-11-c7cf6d943a5b> in train(epoch)
#      11         optimizer.zero_grad()
#      12         # Get output from model
# ---> 13         output = gp_model(train_X_tensor)
#      14         # Calc loss and backprop derivatives
#      15         loss = -mll(output, train_y_tensor)
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/gpytorch/models/exact_gp.py in __call__(self, *args, **kwargs)
#     255                 if not all(torch.equal(train_input, input) for train_input, input in zip(train_inputs, inputs)):
#     256                     raise RuntimeError("You must train on the training inputs!")
# --> 257             res = super().__call__(*inputs, **kwargs)
#     258             return res
#     259
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/gpytorch/module.py in __call__(self, *inputs, **kwargs)
#      26
#      27     def __call__(self, *inputs, **kwargs):
# ---> 28         outputs = self.forward(*inputs, **kwargs)
#      29         if isinstance(outputs, list):
#      30             return [_validate_module_outputs(output) for output in outputs]
#
# <ipython-input-2-f9d215688f0b> in forward(self, x)
#      44         # We're first putting our data through a deep net (feature extractor)
#      45         # We're also scaling the features so that they're nice values
# ---> 46         projected_x = self.space_transform(x)
#      47         projected_x = projected_x - projected_x.min(0)[0]
#      48         projected_x = 2 * (projected_x / projected_x.max(0)[0]) - 1
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Projects/code_deep_kernel_learning/warp_units.py in forward(self, x)
#      80         warped_x = x + weight_constrained * \
#      81             (x - self.r)*torch.exp(-self.a *
# ---> 82                                    torch.square(torch.norm(x-self.r, p=2, dim=1, keepdim=True)))
#      83 #         warped_x = x + self.weight_true*(x - self.r)*torch.exp(-self.a*torch.square(torch.norm(x-self.r, p=2, dim=1, keepdim=True)))
#      84         return warped_x
#
# KeyboardInterrupt:

# %%
# for name, param in gp_model.named_parameters():
#     print(f"Layer:{name} | Size:{param.size()} | Values : {param} \n")

# %%
chessboard_from_model(warp_model)

# %%
oned_map(warp_model.axial_dim0, dim=0)

# %%
chessboard_from_model(warp_model.mobius)

# %%
# for name, param in gp_model.named_parameters():
#     print(f"Layer:{name} | Size:{param.size()} | Values : {param} \n")
#     print(f"Layer:{name} | Size:{param.size()} |  \n")

# %%
likelihood.eval()
gp_model.eval()
gp_model.w1 = 0.2
gp_model.w2 = 0.8
observed_pred = gp_model(coords_tensor)
mean = observed_pred.mean.detach() + train_y_mean
var = observed_pred.variance.detach()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
plot_heatmap(coords, mean, ax=axes[0], cbar=True)
# plot_heatmap(coords, mean, ax=axes[0], vmin=-103, vmax=-63, cbar=True)
plot_heatmap(coords, var, ax=axes[1], cbar=True)

# %%
save_result("result_4", "warpgp", sensor_num, mean.cpu().numpy(), var.cpu().numpy())

# %%
crps(mean.cpu().numpy(), mean.cpu().numpy(), var.cpu().numpy())
# Out:
# array([0.30624863, 0.30112584, 0.29627421, ..., 0.24914439, 0.25012484,
#        0.25111229])

# %%
mse(mean.cpu().numpy(), mean.cpu().numpy(), squared=True)
# Out:
# 0.0

# %%
plot_heatmap(coords, mean)

# %%
point = torch.tensor([[2.5, -2.5]]).to(device)
warp_model(point)

# %%
coords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e1d5c79a0573> in <module>
# ----> 1 coords
#
# NameError: name 'coords' is not defined

# %%
gp_model.covar_module2
# Out:
# ProductKernel(
#   (kernels): ModuleList(
#     (0): LinearKernel(
#       (raw_variance_constraint): Positive()
#     )
#     (1): LinearKernel(
#       (raw_variance_constraint): Positive()
#     )
#   )
# )
