# %%
import gpytorch
import matplotlib.pyplot as plt
import torch
from torch import nn

from func_algorithms import *
from func_data_generation import *
from func_polygon import *
from utils import *
from warp_units import *

# from torchsummary import summary


dtype = torch.double
device = "cuda" if torch.cuda.is_available() else "cpu"
# device =  "cpu"
print("Using {} device".format(device))

import tqdm

torch.set_default_dtype(dtype)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from datetime import datetime

from torch.utils.tensorboard import SummaryWriter
# Out:
# Using cuda device
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class WarpModel(torch.nn.Sequential):
    def __init__(self):
        super(WarpModel, self).__init__()
        self.add_module(
            "axial_dim0", AxialWarpUnit(dim=0, res=100, grad=20, lims=[0, 1.0])
        )
        self.add_module(
            "axial_dim1", AxialWarpUnit(dim=1, res=100, grad=20, lims=[-1.0, 0])
        )
        self.add_module("rbf_seq1", rbfunit_sequential(res=1, ylim=[-1.0, 0.0]))
        self.add_module("rbf_seq2", rbfunit_sequential(res=2, ylim=[-1.0, 0.0]))
        self.add_module("rbf_seq3", rbfunit_sequential(res=3, ylim=[-1, 0]))


#         self.add_module("mobius", MobiusWarpUnit())


class GPRegressionModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood, warp_model):
        super(GPRegressionModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ZeroMean()
        #             self.covar_module = gpytorch.kernels.GridInterpolationKernel(
        #                 gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(ard_num_dims=2)),
        #                 num_dims=2, grid_size=100
        #             )
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
        #         self.covar_module = gpytorch.kernels.SpectralMixtureKernel(
        #             num_mixtures=4, ard_num_dims=2
        #         )
        #         self.covar_module2 = gpytorch.kernels.ScaleKernel(
        #             gpytorch.kernels.PolynomialKernel(1, active_dimes=[0])
        #             * gpytorch.kernels.PolynomialKernel(1, active_dimes=[1])
        #         )
        #         self.covar_module2 = gpytorch.kernels.ScaleKernel(
        #             gpytorch.kernels.PolynomialKernel(power=2)
        #         )
        self.covar_module2 = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
        self.space_transform = warp_model

        #         self.register_parameter(
        #             name="offset", parameter=torch.nn.Parameter(torch.zeros(1, 2))
        #         )

    def forward(self, x):
        # We're first putting our data through a deep net (feature extractor)
        # We're also scaling the features so that they're nice values
        projected_x = self.space_transform(x)
        #         projected_x = projected_x - projected_x.min(0)[0]
        #         projected_x = 2 * (projected_x / projected_x.max(0)[0]) - 1

        mean_x = self.mean_module(x)
        covar_x = self.covar_module(projected_x) + self.covar_module2(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
data_num = 5
sensor_num = 200  # [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

# load data
data_filename = DATA_PATH + "/datasets_" + str(data_num) + ".hd5f"

if os.path.exists(data_filename):
    with h5py.File(data_filename, "r") as f1:
        coords = f1["coords"][...]
        true_rss = f1["true_rss"][...]
        observed_rss = f1["observed_rss"][...]
        train_X = f1["train_" + str(sensor_num) + "/train_X"][...]
        train_y = f1["train_" + str(sensor_num) + "/train_y"][...]
        idx = f1["train_" + str(sensor_num) + "/idx"][...]

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
plot_heatmap(coords, observed_rss, ax=axes[0], robust=True, cbar=True)
plot_heatmap(
    coords,
    observed_rss,
    mask_idx=idx,
    ax=axes[1],
    cbar=True,
)

# %%
# Normalize train_X to 0-1
data_X_tensor = torch.from_numpy(train_X).to(device) / 1000
coords_tensor = torch.from_numpy(coords).to(device) / 1000

train_y_tensor = torch.from_numpy(train_y).to(device)
train_y_mean = train_y_tensor.mean()
data_y_tensor = train_y_tensor - train_y_mean
# train_y_sigma = torch.sqrt(train_y_tensor.var())
# train_y_tensor = (train_y_tensor - train_y_mean) / train_y_sigma

# %%
train_num = int(sensor_num * 1)
train_X_tensor = data_X_tensor[0:train_num, :]
train_y_tensor = data_y_tensor[0:train_num]
test_X_tensor = data_X_tensor[train_num:, :]
test_y_tensor = data_y_tensor[train_num:]

# %%
test_X_tensor.shape
# Out:
# torch.Size([0, 2])

# %%
# Define and initialize model
warp_model = WarpModel().to(device)
likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)
gp_model = GPRegressionModel(
    train_x=train_X_tensor,
    train_y=train_y_tensor,
    likelihood=likelihood,
    warp_model=warp_model,
).to(device)
gp_model.likelihood.noise = 0.2
gp_model.covar_module2.base_kernel.lengthscale = 0.0828
gp_model.covar_module2.outputscale = 30.51

# %%
chessboard_from_model(warp_model)

# %%
for name, param in gp_model.named_parameters():
    print(f"Layer:{name} | Size:{param.size()} | Values : {param} \n")
# #     print(f"Layer:{name} | Size:{param.size()} |  \n")
# Out:
# Layer:likelihood.noise_covar.raw_noise | Size:torch.Size([1]) | Values : Parameter containing:
# tensor([-1.5083], device='cuda:0', requires_grad=True)
#
# Layer:covar_module.raw_outputscale | Size:torch.Size([]) | Values : 0.0
#
# Layer:covar_module.base_kernel.raw_lengthscale | Size:torch.Size([1, 1]) | Values : Parameter containing:
# tensor([[0.]], device='cuda:0', requires_grad=True)
#
# Layer:covar_module2.raw_outputscale | Size:torch.Size([]) | Values : 30.509999999999945
#
# Layer:covar_module2.base_kernel.raw_lengthscale | Size:torch.Size([1, 1]) | Values : Parameter containing:
# tensor([[-2.4496]], device='cuda:0', requires_grad=True)
#
# Layer:space_transform.axial_dim0.weight_true | Size:torch.Size([1, 100]) | Values : Parameter containing:
# tensor([[ 1.3778,  0.5393,  1.3579,  2.2760,  0.6119,  0.7300, -0.6614,  1.9436,
#           0.9483,  0.3371, -0.9658, -0.9491, -0.3407, -1.1125,  1.0709,  0.6015,
#          -0.6618,  1.2274,  1.2010,  0.6254,  0.2924, -0.0996, -0.9877, -1.3676,
#          -0.6722, -0.8132, -0.0997,  0.9681,  1.2283,  1.0263,  0.7703,  1.4576,
#          -0.0076, -1.0859, -0.6271,  0.4334, -0.4210, -0.0315, -1.0067,  0.9083,
#          -0.1681,  0.1086, -0.5209,  1.5815,  0.9701, -0.3636,  1.0173,  1.2152,
#          -0.5276,  0.0283,  0.1405,  0.1843, -1.5275, -1.1930,  0.7718,  1.7938,
#           0.6455, -0.4887, -0.3094, -0.2793,  0.6777, -0.8003,  2.0133, -1.9815,
#          -0.8604, -0.3366,  0.2098,  1.2670,  0.9647, -1.0093, -0.9664, -1.0668,
#          -0.5363, -2.2216,  0.7144, -0.7071,  0.2482,  0.8236, -0.5357, -0.6306,
#           0.4671,  0.4272,  0.8285, -0.1324,  0.1880,  0.7705, -0.3319, -0.0903,
#          -0.3220,  0.3820,  0.0705,  1.3412,  0.3298, -0.2920,  0.1260,  0.5336,
#          -1.3187,  0.4809,  0.4852,  1.4310]], device='cuda:0',
#        requires_grad=True)
#
# Layer:space_transform.axial_dim1.weight_true | Size:torch.Size([1, 100]) | Values : Parameter containing:
# tensor([[ 1.1627,  1.1527,  0.2867,  0.6006,  2.1953, -0.4465,  0.5303, -0.1436,
#           0.1317, -0.1993, -0.3476,  1.4301, -1.0767,  0.0081, -1.3666,  0.2627,
#           0.1315, -0.3757,  0.2423,  0.1959, -0.2208, -1.8829,  1.3014,  0.8042,
#           1.1063,  1.3428,  0.4148,  0.8746,  0.2466, -0.3059, -1.2983,  0.8399,
#           0.8361,  0.7057,  0.6276, -0.5185,  0.8403, -0.5331, -0.4935,  0.7528,
#           0.4027, -0.5018, -0.2906,  0.5616, -2.2504, -1.3328,  0.1503, -0.6171,
#          -0.5168,  0.9195, -0.1670,  1.7945,  0.7126,  0.3833, -0.4412, -1.2820,
#          -0.9206, -0.4582,  0.8540, -0.4281, -0.9505,  0.1699,  0.1349,  0.9297,
#           0.2429, -1.4524, -0.4799, -0.8321,  1.1235,  1.4310, -0.0779,  0.6970,
#           1.2806,  0.8166,  1.8660,  0.9477,  0.0735, -0.0076, -0.5700, -1.8158,
#          -0.0999,  1.4015, -0.1554, -0.1960,  1.0472, -0.3967, -0.0234, -0.6186,
#          -0.3398,  2.2191, -1.2179,  2.0782, -0.1086,  1.7157,  1.5707, -0.6517,
#           0.8506, -0.6686, -0.8962, -1.4149]], device='cuda:0',
#        requires_grad=True)
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num0.weight_true | Size:torch.Size([]) | Values : 0.9912263023658965
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num1.weight_true | Size:torch.Size([]) | Values : 0.9013242191108225
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num2.weight_true | Size:torch.Size([]) | Values : -0.3257568451323398
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num3.weight_true | Size:torch.Size([]) | Values : 0.7391561075210443
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num4.weight_true | Size:torch.Size([]) | Values : 0.21651812395395695
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num5.weight_true | Size:torch.Size([]) | Values : 1.8657690824935214
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num6.weight_true | Size:torch.Size([]) | Values : 1.7358909566609235
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num7.weight_true | Size:torch.Size([]) | Values : 1.1669452253491885
#
# Layer:space_transform.rbf_seq1.rbf_unit_res1num8.weight_true | Size:torch.Size([]) | Values : -0.9923929002447119
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num0.weight_true | Size:torch.Size([]) | Values : 0.4116245827352996
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num1.weight_true | Size:torch.Size([]) | Values : -2.043619267741334
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num2.weight_true | Size:torch.Size([]) | Values : 1.1811564058259465
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num3.weight_true | Size:torch.Size([]) | Values : -1.5555323724304937
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num4.weight_true | Size:torch.Size([]) | Values : 0.30620711382025995
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num5.weight_true | Size:torch.Size([]) | Values : -1.2017389700535819
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num6.weight_true | Size:torch.Size([]) | Values : 1.181230108007319
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2num7.weight_true | Size:torch.Size([]) | Values : 0.7158156963299988
#
# Layer:space_transform.rbf_seq2.rbf_unit_res2
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num713.weight_true | Size:torch.Size([]) | Values : -0.10662023428316769
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num714.weight_true | Size:torch.Size([]) | Values : 0.9749769824092968
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num715.weight_true | Size:torch.Size([]) | Values : -0.4074381362796048
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num716.weight_true | Size:torch.Size([]) | Values : 0.6350861622246547
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num717.weight_true | Size:torch.Size([]) | Values : 1.788187477895623
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num718.weight_true | Size:torch.Size([]) | Values : 0.07274374444756262
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num719.weight_true | Size:torch.Size([]) | Values : -0.26524413075672865
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num720.weight_true | Size:torch.Size([]) | Values : 1.4654822612944256
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num721.weight_true | Size:torch.Size([]) | Values : -0.3018063024258624
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num722.weight_true | Size:torch.Size([]) | Values : 1.2484606774910785
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num723.weight_true | Size:torch.Size([]) | Values : 0.11138543128764639
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num724.weight_true | Size:torch.Size([]) | Values : 0.058530858588031205
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num725.weight_true | Size:torch.Size([]) | Values : -0.7680710783226642
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num726.weight_true | Size:torch.Size([]) | Values : -0.4812624337637149
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num727.weight_true | Size:torch.Size([]) | Values : 1.1135636017973538
#
# Layer:space_transform.rbf_seq3.rbf_unit_res3num728.weight_true | Size:torch.Size([]) | Values : 1.6965572366438704

# %%
# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, gp_model)


def train(epoch):
    gp_model.train()
    likelihood.train()

    for j in range(epoch):
        # Zero backprop gradients
        optimizer.zero_grad()
        # Get output from model
        output = gp_model(train_X_tensor)
        # Calc loss and backprop derivatives
        loss = -mll(output, train_y_tensor)
        loss.backward()

        optimizer.step()
    writer.add_scalar("loss", loss.item(), i)

    writer.add_scalar(
        "length_scale1", gp_model.covar_module.base_kernel.lengthscale.item(), i
    )
    writer.add_scalar("output_scale1", gp_model.covar_module.outputscale.item(), i)
    writer.add_scalar("output_scale", gp_model.covar_module2.outputscale.item(), i)
    writer.add_scalar(
        "length_scale",
        gp_model.covar_module2.base_kernel.lengthscale.item(),
        i,
    )


def test():
    likelihood.eval()
    gp_model.eval()
    observed_pred = gp_model(coords_tensor)
    mean = observed_pred.mean.detach() + train_y_mean
    #     mape = MAPE(test_y_tensor.cpu().numpy(), mean.cpu().numpy())
    mape = MAPE(true_rss, mean.cpu().numpy(), idx)
    writer.add_scalar(
        "mape",
        mape,
        i,
    )
    return mape

# %%
# Use the adam optimizer
optimizer = torch.optim.Adam(
    [
        #         {"params": gp_model.offset, "lr": 0.1},
        {"params": gp_model.space_transform.parameters()},
        {"params": gp_model.covar_module.parameters()},
        #         {"params": gp_model.covar_module2.raw_outputscale},
        {"params": gp_model.covar_module2.parameters()},
        #         {"params": gp_model.mean_module.parameters()},
        {"params": gp_model.likelihood.parameters()},
    ],
    lr=0.01,
)
# gp_model.w1 = 1
# gp_model.w2 = 1

# %%
now = datetime.now()
log_dir = "logs/warpgp/" + now.strftime("%Y%m%d-%H%M%S") + "/"
# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter(log_dir)

mape_store = 1000
iterator = tqdm.notebook.tqdm(range(10000))
for i in iterator:
    train(10)
    mape = test()
    if mape < mape_store:
        mape_store = mape
        state_dict = gp_model.state_dict()
        likelihood_state_dict = likelihood.state_dict()
        torch.save(
            {"model": state_dict, "likelihood": likelihood_state_dict}, "checkpoint.dat"
        )
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-4fab3d045b9d> in <module>
#       7 iterator = tqdm.notebook.tqdm(range(10000))
#       8 for i in iterator:
# ----> 9     train(10)
#      10     mape = test()
#      11     if mape < mape_store:
#
# <ipython-input-24-a21e5ba99397> in train(epoch)
#      16         loss.backward()
#      17
# ---> 18         optimizer.step()
#      19     writer.add_scalar("loss", loss.item(), i)
#      20
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/optim/adam.py in step(self, closure)
#     106
#     107             beta1, beta2 = group['betas']
# --> 108             F.adam(params_with_grad,
#     109                    grads,
#     110                    exp_avgs,
#
# ~/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      83         # Decay the first and second moment running average coefficient
#      84         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 85         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      86         if amsgrad:
#      87             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
# for name, param in gp_model.named_parameters():
#     print(f"Layer:{name} | Size:{param.size()} | Values : {param} \n")

# %%
chessboard_from_model(warp_model)

# %%
oned_map(warp_model.axial_dim0, dim=0)

# %%
chessboard_from_model(warp_model.mobius)

# %%
# for name, param in gp_model.named_parameters():
#     print(f"Layer:{name} | Size:{param.size()} | Values : {param} \n")
#     print(f"Layer:{name} | Size:{param.size()} |  \n")

# %%
likelihood.eval()
gp_model.eval()
# gp_model.w1 = 0.2
# gp_model.w2 = 0.8
observed_pred = gp_model(coords_tensor)
mean = observed_pred.mean.detach() + train_y_mean
var = observed_pred.variance.detach()
# Out:
# /home/nicegeek/miniconda3/envs/GPTor_cuda/lib/python3.8/site-packages/gpytorch/distributions/multivariate_normal.py:259: NumericalWarning: Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-10.
#   warnings.warn(

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
plot_heatmap(coords, mean, ax=axes[0], cbar=True)
# plot_heatmap(coords, mean, ax=axes[0], vmin=-103, vmax=-63, cbar=True)
plot_heatmap(coords, var, ax=axes[1], cbar=True)

# %%
save_result("result_4", "warpgp", sensor_num, mean.cpu().numpy(), var.cpu().numpy())

# %%
crps(mean.cpu().numpy(), mean.cpu().numpy(), var.cpu().numpy())
# Out:
# array([0.30624863, 0.30112584, 0.29627421, ..., 0.24914439, 0.25012484,
#        0.25111229])

# %%
mse(mean.cpu().numpy(), mean.cpu().numpy(), squared=True)
# Out:
# 0.0

# %%
plot_heatmap(coords, mean)

# %%
point = torch.tensor([[2.5, -2.5]]).to(device)
warp_model(point)

# %%
coords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e1d5c79a0573> in <module>
# ----> 1 coords
#
# NameError: name 'coords' is not defined

# %%
gp_model.covar_module2
# Out:
# ProductKernel(
#   (kernels): ModuleList(
#     (0): LinearKernel(
#       (raw_variance_constraint): Positive()
#     )
#     (1): LinearKernel(
#       (raw_variance_constraint): Positive()
#     )
#   )
# )
