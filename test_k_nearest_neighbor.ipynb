# %%
from sklearn.neighbors import NearestNeighbors, KNeighborsRegressor
import torch
import h5py

from func_algorithms import k_nearest_neightbor
from utils import *
from func_data_generation import get_field_data, plot_heatmap

# %load_ext autoreload
# %autoreload 2

# %%
# load data
f = h5py.File('./data/test.hd5f', 'r')
train_X = f['train_X'][...]
train_y = f['train_y'][...]
coords = f['coords'][...]
true_rss = f['true_rss'][...]

# %%
nbs = NearestNeighbors(n_neighbors=10, algorithm='ball_tree').fit(X)
distances, indices = nbs.kneighbors(coords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-646d48277107> in <module>
# ----> 1 nbs = NearestNeighbors(n_neighbors=10, algorithm='ball_tree').fit(X)
#       2 distances, indices = nbs.kneighbors(coords)
#
# NameError: name 'X' is not defined

# %%
predict = k_nearest_neightbor(train_X, train_y, coords, 20)

# %%
fig,ax = plt.subplots()
plot_heatmap(coords, predict, ax=ax, cbar=True)

# %%
fig,ax = plt.subplots()
plot_heatmap(coords, true_rss, ax=ax, cbar=True)
